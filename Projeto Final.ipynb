# %% [markdown]
# # Acidentes nas rodovias federais brasileiras em 2020

# %% [markdown]
# **Integrantes:** José Ítalo Alves de Oliveira Vitorino, Vitor Zimbrunes Pamplona, João de Aquino Lopes Neto

# %% [markdown]
# ## Introdução

# %% [markdown]
# **Esse projeto teve como principal motivação analisar e obter respostas, de como, quando e onde mais ocorrem acidentes nas rodovias federais. Assim como ver a evolução desses incidentes no decorrer do ano.**

# %% [markdown]
# ## Dados

# %% [markdown]
# **A base de dados usada foi a** *datatran2020.csv* **uma parte de uma base do kaggle upado pela polícia federal, nesses dados se tem 31 dimensões, desde data do acidente até tipo de pista onde ocorreu o mesmo.**

# %% [markdown]
# **Inicialmente nós importamos a biblioteca pandas, essa que é onde se tem a maioria das ferramentas usadas nessa análise, também foi importada a seaborn com o intuíto de modificar a interface dos gráficos para ficarem mais amigáveis.**

# %%
import pandas as pd

import seaborn as sns
sns.set_palette('Set2')

# %% [markdown]
# **Após inicializarmos nosso dataframe ao ler o arquivo em csv, utilizamos o comando .head() da biblioteca pandas para ter uma noção inicial de como é a base.**

# %%
df = pd.read_csv('datatran2020-worked.csv')

df.head()
# Out:
#          id data_inversa    dia_semana   horario  uf   br     km    municipio  \
# 0  260031.0   2020-01-01  quarta-feira  01:00:00  TO  153  678.1       GURUPI
# 1  260036.0   2020-01-01  quarta-feira  01:00:00  RJ  116  178.0  NOVA IGUACU
# 2  260037.0   2020-01-01  quarta-feira  01:52:00  SC  101  206.9     SAO JOSE
# 3  260038.0   2020-01-01  quarta-feira  01:15:00  RO  364  236.0       CACOAL
# 4  260039.0   2020-01-01  quarta-feira  01:30:00  PR  153  360.0     REBOUCAS
#
#                  causa_acidente              tipo_acidente  ...  \
# 0              Animais na Pista    Atropelamento de Animal  ...
# 1  Falta de Atenção do Pedestre  Atropelamento de Pedestre  ...
# 2            Ingestão de álcool            Colisão lateral  ...
# 3       Velocidade Incompatível  Saída de leito carroçável  ...
# 4            Ingestão de álcool                Capotamento  ...
#
#   feridos_graves ilesos ignorados feridos veiculos   latitude  longitude  \
# 0              5      0         0       5        1 -11.774602 -49.107450
# 1              0      1         0       0        1 -22.752230 -43.437910
# 2              0      1         0       1        2 -27.591935 -48.618246
# 3              1      0         0       1        1 -11.446246 -61.437612
# 4              4      0         0       6        1 -25.675038 -50.750898
#
#    regional  delegacia             uop
# 0     SR-TO   UOP01/TO  nao cadastrado
# 1     SR-RJ     DEL5/1        UOP02/RJ
# 2     SR-SC     DEL8/1        UOP01/SC
# 3     SR-RO    DEL21/2        UOP02/RO
# 4     SR-PR     DEL7/3        UOP04/PR
#
# [5 rows x 30 columns]

# %% [markdown]
# **Depois de ver como é a base, iremos nos aprofundar um pouco mais nela usando o comando .info() para receber um sumario dos dados**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45368 entries, 0 to 45367
# Data columns (total 30 columns):
# id                        45368 non-null float64
# data_inversa              45368 non-null object
# dia_semana                45368 non-null object
# horario                   45368 non-null object
# uf                        45368 non-null object
# br                        45368 non-null int64
# km                        45368 non-null float64
# municipio                 45368 non-null object
# causa_acidente            45368 non-null object
# tipo_acidente             45368 non-null object
# classificacao_acidente    45368 non-null object
# fase_dia                  45368 non-null object
# sentido_via               45368 non-null object
# condicao_metereologica    45368 non-null object
# tipo_pista                45368 non-null object
# tracado_via               45368 non-null object
# uso_solo                  45368 non-null object
# pessoas                   45368 non-null int64
# mortos                    45368 non-null int64
# feridos_leves             45368 non-null int64
# feridos_graves            45368 non-null int64
# ilesos                    45368 non-null int64
# ignorados                 45368 non-null int64
# feridos                   45368 non-null int64
# veiculos                  45368 non-null int64
# latitude                  45368 non-null float64
# longitude                 45368 non-null float64
# regional                  45368 non-null object
# delegacia                 45368 non-null object
# uop                       45368 non-null object
# dtypes: float64(4), int64(9), object(17)
# memory usage: 7.4+ MB

# %% [markdown]
# ## Pré-Processamento de dados

# %% [markdown]
# **O primeiro passo de todo o projeto, foi alterar um pouco a formatação dos dados, pois estavam em outro tipo de codificação, tivemos que converter para utf-8(Essa conversão foi feita em outro programa), e como a maioria
# dos dados brasileiros os números float estavam separados por ',' e não '.', assim precisamos dar um replace,e as colunas separadas por ';', o que precisou de outro replace**.

# %%
# with open('datatran2020.csv', 'r') as f:
#     result = str(f.read())
#     result = result.replace(",",".")
#     result = result.replace(";",",")
#     f.close
    
# with open('datatran2020-worked.csv', 'w') as f:
#     f.write(result)
#     f.close

# %% [markdown]
# **Utilização de isna().sum() para detectar os valores nulos dos dados.**

# %%
df.isna().sum()
# Out:
# id                        0
# data_inversa              0
# dia_semana                0
# horario                   0
# uf                        0
# br                        0
# km                        0
# municipio                 0
# causa_acidente            0
# tipo_acidente             0
# classificacao_acidente    0
# fase_dia                  0
# sentido_via               0
# condicao_metereologica    0
# tipo_pista                0
# tracado_via               0
# uso_solo                  0
# pessoas                   0
# mortos                    0
# feridos_leves             0
# feridos_graves            0
# ilesos                    0
# ignorados                 0
# feridos                   0
# veiculos                  0
# latitude                  0
# longitude                 0
# regional                  0
# delegacia                 0
# uop                       0
# dtype: int64

# %% [markdown]
# **Atualizando o numero das brs e kilometros, definindo os valores vazios da coluna uop como não cadastrado e trasformando a coluna br em inteiro.**

# %%
df.update(df[['br','km']].fillna('0'))
df.update(df[['uop']].fillna('nao cadastrado'))
df = df.astype({'br': int})

df.br.head()
# Out:
# 0    153
# 1    116
# 2    101
# 3    364
# 4    153
# Name: br, dtype: int32

# %%
df['data_inversa'] = pd.to_datetime(df['data_inversa'])

df['data_inversa'].head()
# Out:
# 0   2020-01-01
# 1   2020-01-01
# 2   2020-01-01
# 3   2020-01-01
# 4   2020-01-01
# Name: data_inversa, dtype: datetime64[ns]

# %% [markdown]
# ## Visualização dos Dados

# %% [markdown]
# **Utilizamos essa parte para respondermos perguntas mais básicas, como...**

# %% [markdown]
# **A média de pessoas envolvidas em acidentes**

# %%
df.pessoas.mean()
# Out:
# 2.3008067360253923

# %% [markdown]
# **Lista dos acidentes categorizados por causa do acidente, e com os numeros de pessoas, mortos, feridos, ilesos, ignorados e veiculos organizados de forma decrescente na coluna mortos.**

# %%
acidentes = df[['pessoas','mortos','feridos_leves','feridos_graves','ilesos','ignorados','veiculos','causa_acidente' ]].groupby(by = 'causa_acidente').sum().sort_values(by = 'mortos', ascending = False)

acidentes
# Out:
#                                                     pessoas  mortos  \
# causa_acidente
# Falta de Atenção à Condução                           36548     860
# Desobediência às normas de trânsito pelo condutor     16422     599
# Velocidade Incompatível                                8766     517
# Falta de Atenção do Pedestre                           2836     403
# Ingestão de álcool                                     7941     225
# Ultrapassagem Indevida                                 2583     221
# Condutor Dormindo                                      3097     180
# Desobediência às normas de trânsito pelo pedestre       715      90
# Defeito Mecânico no Veículo                            5206      87
# Não guardar distância de segurança                     7303      67
# Pista Escorregadia                                     3017      67
# Defeito na Via                                         1548      57
# Animais na Pista                                       1978      57
# Mal Súbito                                              718      53
# Restrição de Visibilidade                               981      44
# Avarias e/ou desgaste excessivo no pneu                1295      37
# Deficiência ou não Acionamento do Sistema de Il...      347      25
# Ingestão de álcool e/ou substâncias psicoativas...      546      21
# Objeto estático sobre o leito carroçável                729      21
# Sinalização da via insuficiente ou inadequada           421      16
# Agressão Externa                                        543      13
# Ingestão de Substâncias Psicoativas                     145       6
# Fenômenos da Natureza                                   290       6
# Carga excessiva e/ou mal acondicionada                  408       5
#
#                                                     feridos_leves  \
# causa_acidente
# Falta de Atenção à Condução                                 14011
# Desobediência às normas de trânsito pelo condutor            5345
# Velocidade Incompatível                                      3673
# Falta de Atenção do Pedestre                                  549
# Ingestão de álcool                                           2429
# Ultrapassagem Indevida                                        826
# Condutor Dormindo                                            1379
# Desobediência às normas de trânsito pelo pedestre             138
# Defeito Mecânico no Veículo                                  2022
# Não guardar distância de segurança                           2385
# Pista Escorregadia                                           1538
# Defeito na Via                                                809
# Animais na Pista                                              880
# Mal Súbito                                                    358
# Restrição de Visibilidade                                     351
# Avarias e/ou desgaste excessivo no pneu                       728
# Deficiência ou não Acionamento do Sistema de Il...             86
# Ingestão de álcool e/ou substâncias psicoativas...            166
# Objeto estático sobre o leito carroçável                      322
# Sinalização da via insuficiente ou inadequada                 156
# Agressão Externa                                              189
# Ingestão de Substâncias Psicoativas                            35
# Fenômenos da Natureza                                         110
# Carga excessiva e/ou mal acondicionada                        153
#
#                                                     feridos_graves  ilesos  \
# causa_acidente
# Falta de Atenção à Condução                                   3869   15398
# Desobediência às normas de trânsito pelo condutor             2127    7029
# Velocidade Incompatível                                       1234    2779
# Falta de Atenção do Pedestre                                   492     977
# Ingestão de álcool                                             829    3862
# Ultrapassagem Indevida                                         423     909
# Condutor Dormindo                                              444     973
# Desobediência às normas de trânsito pelo pedestre              108     255
# Defeito Mecânico no Veículo                                    380    2501
# Não guardar distância de segurança                             447    3934
# Pista Escorregadia                                             265    1042
# Defeito na Via                                                 178     442
# Animais na Pista                                               251     712
# Mal Súbito                                                     119     159
# Restrição de Visibilidade                                      133     388
# Avarias e/ou desgaste excessivo no pneu                        144     343
# Deficiência ou não Acionamento do Sistema de Il...              63     127
# Ingestão de álcool e/ou substâncias psicoativas...              79     233
# Objeto estático sobre o leito carroçável                        83     270
# Sinalização da via insuficiente ou inadequada                   55     171
# Agressão Externa                                                50     227
# Ingestão de Substâncias Psicoativas                             13      77
# Fenômenos da Natureza                                           29     132
# Carga excessiva e/ou mal acondicionada                          26     206
#
#                                                     ignorados  veiculos
# causa_acidente
# Falta de Atenção à Condução                              2410     27388
# Desobediência às normas de trânsito pelo condutor        1322     12312
# Velocidade Incompatível                                   563      5736
# Falta de Atenção do Pedestre                              415      1333
# Ingestão de álcool                                        596      5729
# Ultrapassagem Indevida                                    204      1622
# Condutor Dormindo                                         121      1981
# Desobediência às normas de trânsito pelo pedestre         124       341
# Defeito Mecânico no Veículo                               216      3442
# Não guardar distância de segurança                        470      5623
# Pista Escorregadia                                        105      1777
# Defeito na Via                                             62       955
# Animais na Pista                                           78      1254
# Mal Súbito                                                 29       566
# Restrição de Visibilidade                                  65       666
# Avarias e/ou desgaste excessivo no pneu                    43       727
# Deficiência ou não Acionamento do Sistema de Il...         46       268
# Ingestão de álcool e/ou substâncias psicoativas...         47       344
# Objeto estático sobre o leito carroçável                   33       475
# Sinalização da via insuficiente ou inadequada              23       284
# Agressão Externa                                           64       337
# Ingestão de Substâncias Psicoativas                        14       100
# Fenômenos da Natureza                                      13       209
# Carga excessiva e/ou mal acondicionada                     18       338

# %% [markdown]
# **Utilizamos as medidas de centralidade e dispersão para conhecer como está nossos dados de númericos. Em seguida printamos uma tabela com essas informações e um gráfico que pode ser mais fácil de se entender esses dados**

# %%
measures = pd.DataFrame()

measures['Máximo'] = df.select_dtypes(include=['int64']).max()

measures['Média'] = df.select_dtypes(include=['int64']).mean()

measures['Mediana'] = df.select_dtypes(include=['int64']).median()

d = df.select_dtypes(include=['int64']).mode()

measures['Moda'] = d.iloc[0] 

measures['Desvio Padrão'] = df.select_dtypes(include=['int64']).std()

measures = measures.drop(['br'])

measures
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-3b482674725c> in <module>
#      13 measures['Desvio Padrão'] = df.select_dtypes(include=['int64']).std()
#      14
# ---> 15 measures = measures.drop(['br'])
#      16
#      17 measures
#
# c:\users\first place\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# c:\users\first place\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# c:\users\first place\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# c:\users\first place\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['br'] not found in axis"

# %%
measures.iloc[:,1:].plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Usando a função .boxplot() para plotar os boxplots do dataframe formado pelas colunas numéricas.**

# %%
df.select_dtypes(include=['int64']).iloc[:,1:5].boxplot()
# Out:
# <AxesSubplot:>

# %%
df.select_dtypes(include=['int64']).iloc[:,5:].boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Quais os principais tipos de acidentes nas rodovias federais?

# %% [markdown]
# **Ao verificar nossa tabela, com um mapa de calor temos respostas para todas as vertentes dessa pergunta, onde o tipo de acidente mais ocorrido é a Colisão Traseira, também é esse tipo oque mais envolve pessoas, veículos e feridos, mas se tratando de mortos o tipo de acidente que mais tem mortos é a Colisão Frontal, isso se explica pois colisões frontais são bem mais violentas que as traseiras, nessa tabela também temos médias e porcentagens, para mostrar os tipos que tem maior índice, para o tipo que tem a maior média de pessoas e veículos por acidente, temos o Engavetamento, já aquele que tem a maior probabilidade de se ter uma morte é o Atropelamento ao Pedestre, sendo mais fatal que a Colisão Frontal, em termos de violência esses dois tipos são os mais perigosos, e por último o que deixa a maior porcentagem de feridos é a Queda de ocupante do veículo, que apesar de ter um grande número de feridos tem um baixo indíce de mortes. Ademais temos gráficos para tentar deixar a visualização dos dados mais simples, o primeiro tem o número de acidentes, e o segundo o número de pessoas,mortos e veículos.**

# %%
tipos = df[['pessoas','mortos','feridos','veiculos','tipo_acidente']].groupby('tipo_acidente').sum()

tipos['n_acidentes'] = df.groupby('tipo_acidente').size()
tipos = tipos.sort_values(by= 'n_acidentes',ascending = False)
tipos['mortos %'] = tipos['mortos']/tipos['pessoas']
tipos['feridos %'] = tipos['feridos']/tipos['pessoas']
tipos['média pessoas'] = tipos['pessoas']/tipos['n_acidentes']
tipos['média veículos'] = tipos['veiculos']/tipos['n_acidentes']

format_dict = {'mortos %':'{:.2%}', 'feridos %':'{:.2%}', 'média pessoas': '{:.2f}', 'média veículos': '{:.2f}'}

tipos[['n_acidentes','pessoas','média pessoas','mortos','mortos %','feridos','feridos %','veiculos','média veículos']].style.format(format_dict).background_gradient(cmap='PuBuGn')
# Out:
# <style  type="text/css" >
#     #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow0_col0 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow0_col1 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow0_col2 {
#             background-color:  #a3bcda;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow0_col3 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow0_col4 {
#             background-color:  #ece2f0;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow0_col5 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow0_col6 {
#             background-color:  #7cb0d3;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow0_col7 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow0_col8 {
#             background-color:  #93b7d7;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow1_col0 {
#             background-color:  #015e4c;
#             color:  #f1f1f1;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow1_col1 {
#             background-color:  #499ac6;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow1_col2 {
#             background-color:  #f1e7f3;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow1_col3 {
#             background-color:  #88b3d5;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow1_col4 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow1_col5 {
#             background-color:  #015846;
#             color:  #f1f1f1;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow1_col6 {
#             background-color:  #027e83;
#             color:  #f1f1f1;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow1_col7 {
#             background-color:  #84b2d4;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow1_col8 {
#             background-color:  #fdf4fa;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow2_col0 {
#             background-color:  #1b88a4;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow2_col1 {
#             background-color:  #288cb1;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow2_col2 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow2_col3 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow2_col4 {
#             background-color:  #eae1ef;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow2_col5 {
#             background-color:  #017670;
#             color:  #f1f1f1;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow2_col6 {
#             background-color:  #4799c5;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow2_col7 {
#             background-color:  #2d8db6;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow2_col8 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow3_col0 {
#             background-color:  #2d8db6;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow3_col1 {
#             background-color:  #3a92c1;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow3_col2 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow3_col3 {
#             background-color:  #e1dcec;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow3_col4 {
#             background-color:  #f0e7f2;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow3_col5 {
#             background-color:  #2b8db5;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow3_col6 {
#             background-color:  #6eabd0;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow3_col7 {
#             background-color:  #338fbd;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow3_col8 {
#             background-color:  #9fbbda;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow4_col0 {
#             background-color:  #6aaad0;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow4_col1 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow4_col3 {
#             background-color:  #e7dfee;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow4_col4 {
#             background-color:  #d9d6e9;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow4_col5 {
#             background-color:  #6eabd0;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow4_col6 {
#             background-color:  #01614f;
#             color:  #f1f1f1;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow4_col7 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow4_col8 {
#             background-color:  #fbf2f9;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow5_col0 {
#             background-color:  #8eb5d6;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow5_col1 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow5_col2 {
#             background-color:  #f4ebf5;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow5_col3 {
#             background-color:  #e0dbec;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow5_col4 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow5_col5 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow5_col6 {
#             background-color:  #268bb0;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow5_col7 {
#             background-color:  #d6d5e8;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow5_col8 {
#             background-color:  #f7eef7;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow6_col0 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow6_col1 {
#             background-color:  #88b3d5;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow6_col2 {
#             background-color:  #65a8ce;
#             color:  #000000;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow6_col3 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow6_col4 {
#             background-color:  #016654;
#             color:  #f1f1f1;
#         }    #T_e193f4ae_38f3_11eb_aaed_704d7bcdd70erow6_col5 {
#             background-color:  #549fc9;
#             color:  #000000;

# %%
types = df.groupby('tipo_acidente').size().sort_values(ascending = True)


types.plot.barh(figsize=(8,8))
# Out:
# <AxesSubplot:ylabel='tipo_acidente'>

# %%
tipos = tipos.sort_values(by= 'mortos',ascending = True)

tipos[['pessoas','veiculos','mortos']].plot.barh(figsize=(10,12))
# Out:
# <AxesSubplot:ylabel='tipo_acidente'>

# %% [markdown]
# ### Quais os 20 municipios que mais ocorrem acidentes em rodovias federais?

# %% [markdown]
# **Usamos o mesmo tipo de organização da análise passada, só que dessa vez a dimensão foi os municipios, aqui podemos verificar que uma cidade conseguiu liderar todos os índices númericos, Brasilia é a cidade que mais teve número de acidentes, pessoas envolvidas, mortos, feridos e veiculos, porém nas médias e porcentagens não liderou nenhuma, a cidade com maior média de pessoas por acidente é BETIM, já a com maior porcentagem de mortos é CASCAVEL, a com maior porcentagem de feridos é Uberaba, e a que tem mais veículos envolvidos por acidente é SAO JOSE**

# %%
cities = df[['pessoas','mortos','feridos','veiculos','municipio']].groupby('municipio').sum()

cities['n_acidentes'] = df.groupby('municipio').size()

cities = cities.sort_values(by= 'n_acidentes',ascending = False)[:20]
cities['mortos %'] = cities['mortos']/cities['pessoas']
cities['feridos %'] = cities['feridos']/cities['pessoas']
cities['média pessoas'] = cities['pessoas']/cities['n_acidentes']
cities['média veículos'] = cities['veiculos']/cities['n_acidentes']

format_dict = {'mortos %':'{:.2%}', 'feridos %':'{:.2%}', 'média pessoas': '{:.2f}', 'média veículos': '{:.2f}'}

cities[['n_acidentes','pessoas','média pessoas','mortos','mortos %','feridos','feridos %','veiculos','média veículos']].style.format(format_dict).background_gradient(cmap='PuBuGn')
# Out:
# <style  type="text/css" >
#     #T_e2051874_38f3_11eb_9021_704d7bcdd70erow0_col0 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow0_col1 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow0_col2 {
#             background-color:  #0f8598;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow0_col3 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow0_col4 {
#             background-color:  #8cb5d6;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow0_col5 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow0_col6 {
#             background-color:  #dfdaeb;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow0_col7 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow0_col8 {
#             background-color:  #529ec9;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow1_col0 {
#             background-color:  #016553;
#             color:  #f1f1f1;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow1_col1 {
#             background-color:  #017267;
#             color:  #f1f1f1;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow1_col2 {
#             background-color:  #6cabd0;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow1_col3 {
#             background-color:  #015a49;
#             color:  #f1f1f1;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow1_col4 {
#             background-color:  #7aafd3;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow1_col5 {
#             background-color:  #027f84;
#             color:  #f1f1f1;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow1_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow1_col7 {
#             background-color:  #014d3d;
#             color:  #f1f1f1;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow1_col8 {
#             background-color:  #027c7e;
#             color:  #f1f1f1;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow2_col0 {
#             background-color:  #82b1d4;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow2_col1 {
#             background-color:  #8eb5d6;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow2_col2 {
#             background-color:  #8cb5d6;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow2_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow2_col5 {
#             background-color:  #6cabd0;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow2_col6 {
#             background-color:  #6eabd0;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow2_col7 {
#             background-color:  #4c9bc7;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow2_col8 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow3_col0 {
#             background-color:  #86b3d5;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow3_col1 {
#             background-color:  #82b1d4;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow3_col2 {
#             background-color:  #3a92c1;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow3_col3 {
#             background-color:  #78aed2;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow3_col4 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow3_col5 {
#             background-color:  #8cb5d6;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow3_col6 {
#             background-color:  #e8e0ef;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow3_col7 {
#             background-color:  #5ba3cb;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow3_col8 {
#             background-color:  #016f5f;
#             color:  #f1f1f1;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow4_col0 {
#             background-color:  #9dbad9;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow4_col1 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow4_col2 {
#             background-color:  #80b1d4;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow4_col3 {
#             background-color:  #e3dded;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow4_col4 {
#             background-color:  #e7dfee;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow4_col5 {
#             background-color:  #6cabd0;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow4_col6 {
#             background-color:  #14869d;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow4_col7 {
#             background-color:  #7aafd3;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow4_col8 {
#             background-color:  #027b7d;
#             color:  #f1f1f1;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow5_col0 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow5_col1 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow5_col2 {
#             background-color:  #8cb5d6;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow5_col3 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow5_col4 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow5_col5 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow5_col6 {
#             background-color:  #519ec8;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow5_col7 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow5_col8 {
#             background-color:  #2b8db5;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow6_col0 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow6_col1 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow6_col2 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow6_col3 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow6_col4 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_e2051874_38f3_11eb_9021_704d7bcdd70erow6_col5 {
#             background-color:  #80b1d4;
#             color:  #000000;

# %%
cities['n_acidentes'].sort_values(ascending = True).plot.barh(figsize= (8,8))
# Out:
# <AxesSubplot:ylabel='municipio'>

# %%
cities = cities.sort_values(by= 'n_acidentes',ascending = True)

cities[['pessoas','veiculos','mortos']].plot.barh(figsize=(12,12))
# Out:
# <AxesSubplot:ylabel='municipio'>

# %%
from sklearn.cluster import KMeans
import seaborn as sns

 
cities.plot.scatter(y = 'mortos', x = 'n_acidentes')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='n_acidentes', ylabel='mortos'>

# %%
kmeans = KMeans(n_clusters=3)

kmeans.fit(cities[['mortos','n_acidentes']])
# Out:
# KMeans(n_clusters=3)

# %% [markdown]
# **Ao agrupar as 20 cidades com mais acidentes, podemos observar que pelo número de mortos por número de acidentes, há uma certa variação, porém a um grupo que se destaca, onde se encontram Brasília e Curitiba, as cidades com mais acidentes e mortes no Brasil.**

# %%
sns.scatterplot(data= cities, y = 'mortos', x = 'n_acidentes', hue= kmeans.labels_)
# Out:
# <AxesSubplot:xlabel='n_acidentes', ylabel='mortos'>

# %% [markdown]
# ### Quais partes do dia que mais ocorrem acidentes e mortes em rodovias federais?

# %% [markdown]
# **Seguindo com o mesmo formato de análise, temos 4 fases do dia, onde a fase do dia com mais acidentes, pessoas, feridos e veiculos é o Pleno dia, já a fase com maior número de mortes é Plena Noite, já falando de porcentagens o Amanhecer tem a maior porcentagem de mortes e o Pleno dia a maior porcentagem de feridos, temos o Anoitecer com a maior média de veículos e pessoas por acidente. Adiante temos um gráfico em barra para melhor visualização dos dados, contendo o número de pessoas,veículos e mortos por acidente, e também temos um gráfico em pizza para cada uma dessas medidas.**

# %%
phases = df[['pessoas','mortos','feridos','veiculos','fase_dia']].groupby('fase_dia').sum()

phases['n_acidentes'] = df.groupby('fase_dia').size()

phases = phases.sort_values(by= 'n_acidentes',ascending = False)
phases['mortos %'] = phases['mortos']/phases['pessoas']
phases['feridos %'] = phases['feridos']/phases['pessoas']
phases['média pessoas'] = phases['pessoas']/phases['n_acidentes']
phases['média veículos'] = phases['veiculos']/phases['n_acidentes']

format_dict = {'mortos %':'{:.2%}', 'feridos %':'{:.2%}', 'média pessoas': '{:.2f}', 'média veículos': '{:.2f}'}

phases[['n_acidentes','pessoas','média pessoas','mortos','mortos %','feridos','feridos %','veiculos','média veículos']].style.format(format_dict).background_gradient(cmap='PuBuGn')
# Out:
# <style  type="text/css" >
#     #T_215eed34_38f4_11eb_af51_704d7bcdd70erow0_col0 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow0_col1 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow0_col2 {
#             background-color:  #0e8496;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow0_col3 {
#             background-color:  #1d89a6;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow0_col5 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow0_col6 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow0_col7 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow0_col8 {
#             background-color:  #017369;
#             color:  #f1f1f1;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow1_col0 {
#             background-color:  #2d8db6;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow1_col1 {
#             background-color:  #3b93c2;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow1_col2 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow1_col3 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow1_col4 {
#             background-color:  #017267;
#             color:  #f1f1f1;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow1_col5 {
#             background-color:  #4b9ac6;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow1_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow1_col7 {
#             background-color:  #4397c4;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow1_col8 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow2_col0 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow2_col1 {
#             background-color:  #faf1f8;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow2_col2 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow2_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow2_col4 {
#             background-color:  #e3dded;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow2_col5 {
#             background-color:  #faf1f8;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow2_col6 {
#             background-color:  #4095c3;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow2_col7 {
#             background-color:  #faf1f8;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow2_col8 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow3_col3 {
#             background-color:  #faf1f8;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow3_col4 {
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow3_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow3_col6 {
#             background-color:  #4698c5;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow3_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_215eed34_38f4_11eb_af51_704d7bcdd70erow3_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_215eed34_38f4_11eb_af51_704d7bcdd70e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >n_acidentes</th>        <th class="col_heading level0 col1" >pessoas</th>        <th class="col_heading level0 col2" >média pessoas</th>        <th class="col_heading level0 col3" >mortos</th>        <th class="col_heading level0 col4" >mortos %</th>        <th class="col_heading level0 col5" >feridos</th>        <th class="col_heading level0 col6" >feridos %</th>        <th class="col_heading level0 col7" >veiculos</th>        <th class="col_heading level0 col8" >média veículos</th>    </tr>    <tr>        <th class="index_name level0" >fase_dia</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_215eed34_38f4_11eb_af51_704d7bcdd70elevel0_row0" class="row_heading level0 row0" >Pleno dia</th>
#                         <td id="T_215eed34_38f4_11eb_af51_704d7bcdd70erow0_col0" class="data row0 col0" >24305</td>
#                         <td id="T_215eed34_38f4_11eb_af51_704d7bcdd70erow0_col1" class="data row0 col1" >57048</td>
#                         <td id="T_215eed34_38f4_11eb_af51_704d7bcdd70erow0_col2" class="data row0 col2" >2.35</td>
#                         <td id="T_215eed34_38f4_11eb_af51_704d7bcdd70erow0_col3" class="data row0 col3" >1354</td>
#                         <td id="T_215eed34_38f4_11eb_af51_704d7bcdd70erow0_col4" class="data row0 col4" >2.37%</td>
#                         <td id="T_215eed34_38f4_11eb_af51_704d7bcdd70erow0_col5" class="data row0 col5" >28227</td>
#                         <td id="T_215eed34_38f4_11eb_af51_704d7bcdd70erow0_col6" class="data row0 col6" >49.48%</td>
#                         <td id="T_215eed34_38f4_11eb_af51_704d7bcdd70erow0_col7" class="data row0 col7" >40870</td>
#                         <td id="T_215eed34_38f4_11eb_af51_704d7bcdd70erow0_col8" class="data row0 col8" >1.68</td>
#             </tr>
#             <tr>
#                         <th id="T_215eed34_38f4_11eb_af51_704d7bcdd70elevel0_row1" class="row_heading level0 row1" >Plena Noite</th>
#                         <td id="T_215eed34_38f4_11eb_af51_704d7bcdd70erow1_col0" class="data row1 col0" >16430</td>
#                         <td id="T_215eed34_38f4_11eb_af51_704d7bcdd70erow1_col1" class="data row1 col1" >36660</td>
#                         <td id="T_215eed34_38f4_11eb_af51_704d7bcdd70erow1_col2" class="data row1 col2" >2.23</td>
#                         <td id="T_215eed34_38f4_11eb_af51_704d7bcdd70erow1_col3" class="data row1 col3" >1890</td>
#                         <td id="T_215eed34_38f4_11eb_af51_704d7bcdd70erow1_col4" class="data row1 col4" >5.16%</td>
#                         <td id="T_215eed34_38f4_11eb_af51_704d7bcdd70erow1_col5" class="data row1 col5" >17094</td>
#                         <td id="T_215eed34_38f4_11eb_af51_704d7bcdd70erow1_col6" class="data row1 col

# %%
phases[['pessoas','veiculos','mortos']].plot.bar(figsize=(7,7))
# Out:
# <AxesSubplot:xlabel='fase_dia'>

# %%
phases['pessoas'].plot.pie()
# Out:
# <AxesSubplot:ylabel='pessoas'>

# %%
phases['mortos'].plot.pie()
# Out:
# <AxesSubplot:ylabel='mortos'>

# %%
phases['feridos'].plot.pie()
# Out:
# <AxesSubplot:ylabel='feridos'>

# %% [markdown]
# ### Análise de datas

# %% [markdown]
# **Ao se analisar as datas, principalmente a parte dos meses, se percebe uma queda considerável no número de acidentes, a causa dessa diminuição no número de acidentes é a pandemia ocasionada pelo covid-19. Já analisando os dias com mais acidentes, podemos ver que os 3 dias do fim de semana, sexta,sábado e domingo, dominam com os números mais alto de acidentes.**

# %%
df.groupby(df['data_inversa'].dt.strftime('%B')).size().sort_values(ascending = False).to_frame().rename(columns={0:'Quantidade'})
# Out:
#               Quantidade
# data_inversa
# September           5629
# August              5624
# January             5497
# February            5467
# July                5117
# March               4784
# June                4723
# May                 4649
# April               3878

# %%
months = df.groupby(df['data_inversa'].dt.month).size().to_frame().rename(columns={0:'Quantidade'})

import calendar
months.rename(index= lambda x: calendar.month_abbr[x]).plot.line()
# Out:
# c:\users\first place\appdata\local\programs\python\python37-32\lib\site-packages\pandas\plotting\_matplotlib\core.py:1182: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='data_inversa'>

# %%
df.groupby('dia_semana').size().sort_values(ascending = False).to_frame().rename(columns={0:'Quantidade'})
# Out:
#                Quantidade
# dia_semana
# sábado               7476
# domingo              7436
# sexta-feira          7043
# segunda-feira        6092
# quarta-feira         5923
# quinta-feira         5772
# terça-feira          5626

# %% [markdown]
# ## Conclusão

# %% [markdown]
# **Os resultados encontrados nos permite identificar que: o acidente mais recorrente nas rodovias é a colisão traseira e que a colisão frontal é o tipo mais mortal; O município com maior número de acidentes, pessoas, mortos, feridos e veículos é Brasília; A parte do dia com mais acidentes, pessoas, feridos e veículos é em pleno dia. Esses dados são de extrema importância para saber como podemos melhorar o trânsito nas rodovias federais e que mudanças devem ser feitas para diminuir o número de acidentes, com esses dados se tem mais precisam nos locais que mais necessitam das mudanças assim como horário e forma de acidente mais ocorrente. Com isso conseguimos responder as questões propostas para o trabalho, possíveis melhorias podem ser feitas como uma atualização do projeto a cada novo dado que o Detran fornece sobre o trânsito assim como pode-se incluir o trânsito dentro dos municípios. Uma das limitações foi a interpretação de alguns dados do Detran que é necessário uma maior análise sobre eles.**
